# %% [markdown]
# # Survey of Household Economics and Decisionmaking Data
#
# Author: Dhruval Bhatt

# %%
import pandas as pd
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# About this data: it has 11,316 respondants

# %%
df_18 = pd.read_csv('2018_data.csv', encoding = "ISO-8859-1")
df_17 = pd.read_csv('2017_data.csv', encoding = "ISO-8859-1")
df_16 = pd.read_csv('2016_data.csv', encoding = "ISO-8859-1")
df_15 = pd.read_csv('2015_data.csv', encoding = "ISO-8859-1")
df_14 = pd.read_csv('2014_data.csv', encoding = "ISO-8859-1")
df_13 = pd.read_csv('2013_data.csv', encoding = "ISO-8859-1")

# %%
# Where do people work? 

survey18_df['D3A'].value_counts().plot('bar')

# %%
df_17 = pd.read_csv('Data/SHED/2017_data.csv', encoding = "ISO-8859-1")
df_16 = pd.read_csv('Data/SHED/2016_data.csv', encoding = "ISO-8859-1")
df_15 = pd.read_csv('Data/SHED/2015_data.csv', encoding = "ISO-8859-1")
df_14 = pd.read_csv('Data/SHED/2014_data.csv', encoding = "ISO-8859-1")
df_13 = pd.read_csv('Data/SHED/2013_data.csv', encoding = "ISO-8859-1")
